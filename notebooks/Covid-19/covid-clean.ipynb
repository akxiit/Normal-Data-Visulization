# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('D:/Project/Normal-Data-Visulization/datasets/Covid-19/covid_19_clean_complete.csv')

# %%
df
# Out:
#       Province/State         Country/Region        Lat       Long        Date  \
# 0                NaN            Afghanistan  33.939110  67.709953  2020-01-22
# 1                NaN                Albania  41.153300  20.168300  2020-01-22
# 2                NaN                Algeria  28.033900   1.659600  2020-01-22
# 3                NaN                Andorra  42.506300   1.521800  2020-01-22
# 4                NaN                 Angola -11.202700  17.873900  2020-01-22
# ...              ...                    ...        ...        ...         ...
# 49063            NaN  Sao Tome and Principe   0.186400   6.613100  2020-07-27
# 49064            NaN                  Yemen  15.552727  48.516388  2020-07-27
# 49065            NaN                Comoros -11.645500  43.333300  2020-07-27
# 49066            NaN             Tajikistan  38.861000  71.276100  2020-07-27
# 49067            NaN                Lesotho -29.610000  28.233600  2020-07-27
#
# ...

# %% [markdown]
# What are the total number of rows and columns in the dataset?

# %%
len(df.index) , len(df.columns)
# Out:
# (49068, 10)

# %% [markdown]
# How many unique countries are listed in the dataset?

# %%
len(np.unique(df['Country/Region']))
# Out:
# 187

# %% [markdown]
# Extract all rows where the WHO Region is "Europe."

# %%
df[df['WHO Region'] == 'Europe']
# Out:
#                     Province/State  Country/Region      Lat     Long  \
# 1                              NaN         Albania  41.1533  20.1683
# 3                              NaN         Andorra  42.5063   1.5218
# 7                              NaN         Armenia  40.0691  45.0382
# 16                             NaN         Austria  47.5162  14.5501
# 17                             NaN      Azerbaijan  40.1431  47.5769
# ...                            ...             ...      ...      ...
# 49053       British Virgin Islands  United Kingdom  18.4207 -64.6400
# 49054     Turks and Caicos Islands  United Kingdom  21.6940 -71.7979
# 49059  Falkland Islands (Malvinas)  United Kingdom -51.7963 -59.5236
# 49060    Saint Pierre and Miquelon          France  46.8852 -56.3159
# 49066                          NaN      Tajikistan  38.8610  71.2761
#
#              Date  Confirmed  Deaths  Recovered  Active WHO Region
# 1      2020-01-22          0       0          0       0     Europe
# ...

# %% [markdown]
# Find all records where the number of Confirmed cases is greater than 10,000.

# %%
df[df['Confirmed'] > 10000]
# Out:
#       Province/State      Country/Region        Lat        Long        Date  \
# 2932           Hubei               China  30.975600  112.270700  2020-02-02
# 3193           Hubei               China  30.975600  112.270700  2020-02-03
# 3454           Hubei               China  30.975600  112.270700  2020-02-04
# 3715           Hubei               China  30.975600  112.270700  2020-02-05
# 3976           Hubei               China  30.975600  112.270700  2020-02-06
# ...              ...                 ...        ...         ...         ...
# 49028            NaN      United Kingdom  55.378100   -3.436000  2020-07-27
# 49030            NaN                  US  40.000000 -100.000000  2020-07-27
# 49031            NaN          Uzbekistan  41.377491   64.585262  2020-07-27
# 49032            NaN           Venezuela   6.423800  -66.589700  2020-07-27
# 49044            NaN  West Bank and Gaza  31.952200   35.233200  2020-07-27
#
# ...

# %% [markdown]
# Sort the dataset by Confirmed cases in descending order.

# %%
df.sort_values(by='Confirmed', ascending=False)
# Out:
#       Province/State       Country/Region        Lat        Long        Date  \
# 49030            NaN                   US  40.000000 -100.000000  2020-07-27
# 48769            NaN                   US  40.000000 -100.000000  2020-07-26
# 48508            NaN                   US  40.000000 -100.000000  2020-07-25
# 48247            NaN                   US  40.000000 -100.000000  2020-07-24
# 47986            NaN                   US  40.000000 -100.000000  2020-07-23
# ...              ...                  ...        ...         ...         ...
# 43            Quebec               Canada  52.939900  -73.549100  2020-01-22
# 5                NaN  Antigua and Barbuda  17.060800  -61.796400  2020-01-22
# 0                NaN          Afghanistan  33.939110   67.709953  2020-01-22
# 19               NaN              Bahrain  26.027500   50.550000  2020-01-22
# 18               NaN              Bahamas  25.025885  -78.035889  2020-01-22
#
# ...

# %% [markdown]
# Calculate the total number of Deaths for each WHO Region.

# %%
df.groupby('WHO Region')['Deaths'].sum()
# Out:
# WHO Region
# Africa                     439978
# Americas                 19359292
# Eastern Mediterranean     1924029
# Europe                   19271040
# South-East Asia           1458134
# Western Pacific            932430
# Name: Deaths, dtype: int64

# %% [markdown]
# Determine the country with the highest total Recovered cases.

# %%
df.loc[df['Recovered'].idxmax()]['Country/Region']
# Out:
# 'Brazil'

# %% [markdown]
# Group the data by Date and calculate the total Confirmed cases for each day.

# %%
df.groupby('Date')['Confirmed'].sum()
# Out:
# Date
# 2020-01-22         555
# 2020-01-23         654
# 2020-01-24         941
# 2020-01-25        1434
# 2020-01-26        2118
#                 ...
# 2020-07-23    15510481
# 2020-07-24    15791645
# 2020-07-25    16047190
# 2020-07-26    16251796
# 2020-07-27    16480485
# Name: Confirmed, Length: 188, dtype: int64

# %% [markdown]
# Find the average Active cases for each WHO Region.

# %%
df.groupby('WHO Region')['Active'].mean()
# Out:
# WHO Region
# Africa                    1125.678081
# Americas                 26113.836494
# Eastern Mediterranean     5828.858801
# Europe                    7074.912101
# South-East Asia          12569.097872
# Western Pacific            636.366634
# Name: Active, dtype: float64

# %% [markdown]
# Identify how many null values exist in the Province/State column.

# %%
df['Province/State'].isna().count()
# Out:
# np.int64(49068)

# %% [markdown]
# Replace null values in the Province/State column with "Unknown".

# %%
df['Province/State'].fillna('Unknown', inplace=True)
# Out:
# D:\Temp\ipykernel_15824\3646580923.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Province/State'].fillna('Unknown', inplace=True)

# %%
df
# Out:
#       Province/State         Country/Region        Lat       Long        Date  \
# 0            Unknown            Afghanistan  33.939110  67.709953  2020-01-22
# 1            Unknown                Albania  41.153300  20.168300  2020-01-22
# 2            Unknown                Algeria  28.033900   1.659600  2020-01-22
# 3            Unknown                Andorra  42.506300   1.521800  2020-01-22
# 4            Unknown                 Angola -11.202700  17.873900  2020-01-22
# ...              ...                    ...        ...        ...         ...
# 49063        Unknown  Sao Tome and Principe   0.186400   6.613100  2020-07-27
# 49064        Unknown                  Yemen  15.552727  48.516388  2020-07-27
# 49065        Unknown                Comoros -11.645500  43.333300  2020-07-27
# 49066        Unknown             Tajikistan  38.861000  71.276100  2020-07-27
# 49067        Unknown                Lesotho -29.610000  28.233600  2020-07-27
#
# ...

# %% [markdown]
# Convert the Date column to datetime format and find the earliest and latest dates in the dataset.

# %%
time = pd.to_datetime(df['Date'])
df['Date'].sort_values()[0]
# Out:
# '2020-01-22'

# %% [markdown]
# Create a NumPy array of the Confirmed cases and calculate the mean, median, and standard deviation.

# %%
arr = np.array(df['Confirmed'])
arr.mean() , arr.std() , np.median(arr)
# Out:
# (np.float64(16884.90425531915),
#  np.float64(127298.90808415522),
#  np.float64(168.0))

# %% [markdown]
# Plot a line graph showing the total Confirmed cases over time.

# %%
plt.plot('Confirmed' , 'Date' , data=df)

# %% [markdown]
# Create a bar chart showing the total Deaths for the top 5 countries.

# %%
country = df.groupby('Country/Region')['Deaths'].sum().sort_values(ascending=False).head(5)

plt.bar(country.index , country.values)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# Use Seaborn to create a heatmap showing the correlation between Confirmed, Deaths, Recovered, and Active cases.

# %%
corr_matrix = df[['Confirmed', 'Deaths', 'Recovered', 'Active']].corr()

sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# Create a scatter plot to visualize the relationship between Confirmed and Deaths.

# %%
plt.scatter('Confirmed', 'Deaths', data=df)

# %% [markdown]
# Extract all rows where the Date is after "2020-03-01"

# %%
df['Date'] = pd.to_datetime(df['Date'])
df[df['Date'] >= '2020-03-01']
# Out:
#       Province/State         Country/Region        Lat       Long       Date  \
# 10179        Unknown            Afghanistan  33.939110  67.709953 2020-03-01
# 10180        Unknown                Albania  41.153300  20.168300 2020-03-01
# 10181        Unknown                Algeria  28.033900   1.659600 2020-03-01
# 10182        Unknown                Andorra  42.506300   1.521800 2020-03-01
# 10183        Unknown                 Angola -11.202700  17.873900 2020-03-01
# ...              ...                    ...        ...        ...        ...
# 49063        Unknown  Sao Tome and Principe   0.186400   6.613100 2020-07-27
# 49064        Unknown                  Yemen  15.552727  48.516388 2020-07-27
# 49065        Unknown                Comoros -11.645500  43.333300 2020-07-27
# 49066        Unknown             Tajikistan  38.861000  71.276100 2020-07-27
# 49067        Unknown                Lesotho -29.610000  28.233600 2020-07-27
#
# ...

# %% [markdown]
# Find the total number of Active cases on "2020-06-01"

# %%
df[df['Date'] == '2020-06-01']['Active'].sum()
# Out:
# np.int64(3264452)

# %% [markdown]
# Calculate the total Confirmed, Deaths, and Recovered for each country.

# %%
df.groupby('Country/Region')[['Confirmed' , 'Deaths' , 'Recovered']].sum()
# Out:
#                     Confirmed  Deaths  Recovered
# Country/Region
# Afghanistan           1936390   49098     798240
# Albania                196702    5708     118877
# Algeria               1179755   77972     755897
# Andorra                 94404    5423      69074
# Angola                  22662    1078       6573
# ...                       ...     ...        ...
# West Bank and Gaza     233461    1370      61124
# Western Sahara            901      63        648
# Yemen                   67180   17707      23779
# Zambia                 129421    2643      83611
# Zimbabwe                50794     881      12207
#
# [187 rows x 3 columns]
